# %%
import pandas as pd
import os

# Ensure the correct working directory
os.chdir('/Users/nsusser/Desktop/Github/yfinance/')

# Read in the data
data = pd.read_csv("processed_data.csv")

print(data['Themes'][1])
# Out:
# CRISISLEX_CRISISLEXREC;WB_2433_CONFLICT_AND_VIOLENCE;WB_2432_FRAGILITY_CONFLICT_AND_VIOLENCE;UNGP_CRIME_VIOLENCE;TAX_ETHNICITY;TAX_ETHNICITY_IRANIAN;SECURITY_SERVICES;TAX_FNCACT;TAX_FNCACT_POLICE;CRISISLEX_C07_SAFETY;TAX_FNCACT_OFFICER;TAX_FNCACT_POLICE_OFFICER;KILL;TAX_FNCACT_OFFICIAL;WB_678_DIGITAL_GOVERNMENT;WB_694_BROADCAST_AND_MEDIA;WB_133_INFORMATION_AND_COMMUNICATION_TECHNOLOGIES;TAX_FNCACT_POLICEMAN;CRISISLEX_T03_DEAD;GENERAL_GOVERNMENT;EPU_POLICY;EPU_POLICY_GOVERNMENT;PROTEST;MOVEMENT_GENERAL;TAX_FNCACT_DEMONSTRATORS;EPU_ECONOMY;EPU_ECONOMY_HISTORIC;WOUND;CRISISLEX_T02_INJURED;ARMEDCONFLICT;MEDIA_MSM;ACT_FORCEPOSTURE;ARREST;SOC_GENERALCRIME;LEADER;TAX_FNCACT_PRESIDENT;USPEC_POLITICS_GENERAL1;TAX_ETHNICITY_AMERICAN;

# %%
#clean Themes column
themes_list = [item.replace('_', ' ') for item in data['Themes'][1].split(';') if item]

print(themes_list)
# Out:
# ['CRISISLEX CRISISLEXREC', 'WB 2433 CONFLICT AND VIOLENCE', 'WB 2432 FRAGILITY CONFLICT AND VIOLENCE', 'UNGP CRIME VIOLENCE', 'TAX ETHNICITY', 'TAX ETHNICITY IRANIAN', 'SECURITY SERVICES', 'TAX FNCACT', 'TAX FNCACT POLICE', 'CRISISLEX C07 SAFETY', 'TAX FNCACT OFFICER', 'TAX FNCACT POLICE OFFICER', 'KILL', 'TAX FNCACT OFFICIAL', 'WB 678 DIGITAL GOVERNMENT', 'WB 694 BROADCAST AND MEDIA', 'WB 133 INFORMATION AND COMMUNICATION TECHNOLOGIES', 'TAX FNCACT POLICEMAN', 'CRISISLEX T03 DEAD', 'GENERAL GOVERNMENT', 'EPU POLICY', 'EPU POLICY GOVERNMENT', 'PROTEST', 'MOVEMENT GENERAL', 'TAX FNCACT DEMONSTRATORS', 'EPU ECONOMY', 'EPU ECONOMY HISTORIC', 'WOUND', 'CRISISLEX T02 INJURED', 'ARMEDCONFLICT', 'MEDIA MSM', 'ACT FORCEPOSTURE', 'ARREST', 'SOC GENERALCRIME', 'LEADER', 'TAX FNCACT PRESIDENT', 'USPEC POLITICS GENERAL1', 'TAX ETHNICITY AMERICAN']
