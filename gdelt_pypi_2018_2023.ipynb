# %%
# %pip install gdelt
# %pip install pandas
import gdelt from gdelt
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# https://pypi.org/project/gdelt/
# this is the library
# http://data.gdeltproject.org/documentation/GDELT-Data_Format_Codebook.pdf
#
# http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_Codebook-V2.1.pdf
#
# https://www.gdeltproject.org/data.html

# %%
gd2 = gdelt.gdelt(version=2)
news_data= gd2.Search(['2018 01 01','2024 01 01'], translation=True, table='gkg', output='pd')

# Print the DataFrame
print(news_data.head())
print(news_data.shape)
print(news_data.columns)
print(len(news_data))
# Out:
# /Users/nsusser/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/nsusser/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/nsusser/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ...

# %%
news_data.to_csv('news_data.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 column_names = news_data.columns.tolist()
#       2 print(column_names)
#
# NameError: name 'news_data' is not defined
