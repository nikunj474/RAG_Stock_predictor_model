# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#      |████████████████████████████████| 101 kB 9.3 MB/s ta 0:00:011
# ...
#      |████████████████████████████████| 939 kB 26.3 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))': /simple/lxml/
# ...
#      |████████████████████████████████| 4.5 MB 47.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 147 kB 16.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 508 kB 32.7 MB/s eta 0:00:01
# ...
#   Created wheel for peewee: filename=peewee-3.17.7-cp38-cp38-macosx_10_9_x86_64.whl size=282923 sha256=d05da6d83c6a37befd7a93638bf71e396e5f31505aa09c9b08b92f0107522898
# ...

# %%
import yfinance as yf
# Out:
# /Users/nsusser/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
msft = yf.Ticker('MSFT')

# return a df
hist = msft.history(period='1mo')

# %%
msft = yf.Ticker('TSLA')

# return a df
tsla_hist = msft.history(start='2019-12-31', end='2020-01-10')

# %%
tsla_hist
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-12-31 00:00:00-05:00  27.000000  28.086000  26.805332  27.888666
# 2020-01-02 00:00:00-05:00  28.299999  28.713333  28.114000  28.684000
# 2020-01-03 00:00:00-05:00  29.366667  30.266666  29.128000  29.534000
# 2020-01-06 00:00:00-05:00  29.364668  30.104000  29.333332  30.102667
# 2020-01-07 00:00:00-05:00  30.760000  31.441999  30.224001  31.270666
# 2020-01-08 00:00:00-05:00  31.580000  33.232666  31.215334  32.809334
# 2020-01-09 00:00:00-05:00  33.139999  33.253334  31.524668  32.089333
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-12-31 00:00:00-05:00  154285500        0.0           0.0
# 2020-01-02 00:00:00-05:00  142981500        0.0           0.0
# 2020-01-03 00:00:00-05:00  266677500        0.0           0.0
# 2020-01-06 00:00:00-05:00  151995000        0.0           0.0
# 2020-01-07 00:00:00-05:00  268231500        0.0           0.0
# ...

# %%
hist.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-09-25 00:00:00-04:00  252.539993  257.049988  252.279999  257.019989
# 2024-09-26 00:00:00-04:00  260.600006  261.750000  251.529999  254.220001
# 2024-09-27 00:00:00-04:00  257.380005  260.700012  254.119995  260.459991
# 2024-09-30 00:00:00-04:00  259.040009  264.859985  255.770004  261.630005
# 2024-10-01 00:00:00-04:00  262.670013  263.980011  248.529999  258.019989
# 2024-10-02 00:00:00-04:00  247.550003  251.160004  241.500000  249.020004
# 2024-10-03 00:00:00-04:00  244.479996  249.789993  237.809998  240.660004
# 2024-10-04 00:00:00-04:00  246.690002  250.960007  244.580002  250.080002
# 2024-10-07 00:00:00-04:00  249.000000  249.830002  240.699997  240.830002
# 2024-10-08 00:00:00-04:00  243.559998  246.210007  240.559998  244.500000
# 2024-10-09 00:00:00-04:00  243.820007  247.429993  239.509995  241.050003
# 2024-10-10 00:00:00-04:00  241.809998  242.789993  232.339996  238.770004
# ...

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'TSLA',
#  'exchangeName': 'NMS',
#  'fullExchangeName': 'NasdaqGS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 1277818200,
#  'regularMarketTime': 1729884060,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 266.84,
#  'fiftyTwoWeekHigh': 269.44,
#  'fiftyTwoWeekLow': 255.32,
#  'regularMarketDayHigh': 269.44,
#  'regularMarketDayLow': 255.32,
#  'regularMarketVolume': 141467020,
#  'longName': 'Tesla, Inc.',
#  'shortName': 'Tesla, Inc.',
#  'chartPreviousClose': 27.647,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1729843200,
#    'end': 1729863000,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1729863000,
#    'end': 1729886400,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1729886400,
#    'end': 1729900800,
#    'gmtoffset': -14400}},
# ...

# %%
msft.info
# Out:
# {'address1': '1 Tesla Road',
#  'city': 'Austin',
#  'state': 'TX',
#  'zip': '78725',
#  'country': 'United States',
#  'phone': '512 516 8177',
#  'website': 'https://www.tesla.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
msft.get_shares_full(start='2022-01-01', end=None) # a series of full shares on each day
# Out:
# 2022-02-04 00:00:00-05:00    1020630016
# 2022-02-05 00:00:00-05:00    1004259968
# 2022-02-08 00:00:00-05:00    1033510016
# 2022-02-11 00:00:00-05:00    1033510016
# 2022-03-04 00:00:00-05:00    1083500032
#                                 ...
# 2024-10-16 00:00:00-04:00    3194639872
# 2024-10-18 00:00:00-04:00    3194639872
# 2024-10-19 00:00:00-04:00    3194639872
# 2024-10-24 00:00:00-04:00    3194639872
# 2024-10-25 00:00:00-04:00    3210060032
# Length: 249, dtype: int64

# %%
msft.calendar
# Out:
# {'Dividend Date': datetime.date(2024, 12, 11),
#  'Ex-Dividend Date': datetime.date(2024, 11, 20),
#  'Earnings Date': [datetime.date(2024, 10, 30)],
#  'Earnings High': 3.17,
#  'Earnings Low': 2.96,
#  'Earnings Average': 3.09,
#  'Revenue High': 65196500000,
#  'Revenue Low': 64221700000,
#  'Revenue Average': 64479400000}

# %%
msft.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0701  222486933
# 1    2023-06-30                     Blackrock Inc.   0.0586  185889398
# 2    2023-06-30           State Street Corporation   0.0328  104115390
# 3    2023-06-30      Geode Capital Management, LLC   0.0163   51656526
# 4    2023-06-30            Capital World Investors   0.0133   42272512
# 5    2023-06-30                           FMR, LLC   0.0091   28771552
# 6    2022-12-31  Norges Bank Investment Management   0.0088   28085245
# 7    2023-06-30                     Morgan Stanley   0.0088   27983350
# 8    2023-06-30      Price (T.Rowe) Associates Inc   0.0088   27984161
# 9    2023-06-30          JP Morgan Chase & Company   0.0084   26739940
#
#          Value
# 0  58240404451
# 1  48660267714
# 2  27254285640
# 3  13522128811
# 4  11065675466
# 5   7531529167
# 6   3459540479
# 7   7325201529
# 8   7325413824
# 9   6999714093

# %%
msft.mutualfund_holders
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2023-06-30             Vanguard Total Stock Market Index Fund   0.0265
# 1    2023-06-30                            Vanguard 500 Index Fund   0.0202
# 2    2023-05-31                            Fidelity 500 Index Fund   0.0095
# 3    2023-08-31                             SPDR S&P 500 ETF Trust   0.0094
# 4    2023-08-31        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   0.0079
# 5    2023-08-31                           iShares Core S&P 500 ETF   0.0079
# 6    2023-06-30                         Growth Fund Of America Inc   0.0074
# 7    2023-06-30                         Vanguard Growth Index Fund   0.0072
# 8    2023-06-30  Vanguard Institutional Index Fund-Institutiona...   0.0058
# 9    2023-08-31     Select Sector SPDR Fund-Consumer Discretionary   0.0041
#
#      Shares        Value
# 0  84022098  21994464593
# 1  64144346  16791065452
# 2  30095622   6137400194
# 3  29683481   7660712776
# ...

# %%
msft.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          4    4     8     6           1
# 1    -1m          8   14    20     8           4
# 2    -2m          7   12    20     8           4
# 3    -3m          7   12    21     6           4

# %%
msft.analyst_price_targets
# Out:
# {'current': 267.36,
#  'low': 24.86,
#  'high': 310.0,
#  'mean': 213.65,
#  'median': 221.0}

# %%
msft.earnings_estimate
# Out:
#      numberOfAnalysts    avg    low   high  yearAgoEps  growth
# 0q                 30   3.09   2.96   3.17        2.73   0.132
# +1q                30   3.22   3.07   3.37        2.93   0.099
# 0y                 42  13.07  12.74  13.64       11.80   0.108
# +1y                41  15.22  14.23  16.26       13.07   0.164

# %%
data = yf.download('goog', period='1mo')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           GOOG        GOOG        GOOG        GOOG
# Date
# 2024-09-25 00:00:00+00:00  162.990005  162.990005  164.216995  162.774994
# 2024-09-26 00:00:00+00:00  163.830002  163.830002  165.500000  163.500000
# 2024-09-27 00:00:00+00:00  165.289993  165.289993  166.970001  163.830002
# 2024-09-30 00:00:00+00:00  167.190002  167.190002  167.360001  164.639999
# 2024-10-01 00:00:00+00:00  168.419998  168.419998  170.440002  165.899994
# 2024-10-02 00:00:00+00:00  167.309998  167.309998  168.880005  166.250000
# 2024-10-03 00:00:00+00:00  167.210007  167.210007  167.910004  165.369995
# 2024-10-04 00:00:00+00:00  168.559998  168.559998  169.550003  166.960007
# 2024-10-07 00:00:00+00:00  164.389999  164.389999  169.899994  164.130005
# 2024-10-08 00:00:00+00:00  165.699997  165.699997  166.100006  164.309998
# ...

# %%
data.dtypes
# Out:
# Price      Ticker
# Adj Close  AAPL      float64
#            GOOG      float64
# Close      AAPL      float64
#            GOOG      float64
# High       AAPL      float64
#            GOOG      float64
# Low        AAPL      float64
#            GOOG      float64
# Open       AAPL      float64
#            GOOG      float64
# Volume     AAPL        int64
#            GOOG        int64
# dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
tech = yf.Sector('technology')
tech.top_companies
# Out:
#                                                 name rating  market weight
# symbol
# AAPL                                      Apple Inc.    Buy       0.187372
# NVDA                              NVIDIA Corporation    Buy       0.185124
# MSFT                           Microsoft Corporation    Buy       0.169331
# AVGO                                   Broadcom Inc.    Buy       0.043168
# ORCL                              Oracle Corporation    Buy       0.025594
# CRM                                 Salesforce, Inc.    Buy       0.014730
# AMD                     Advanced Micro Devices, Inc.    Buy       0.013443
# ACN                                    Accenture plc    Buy       0.011976
# CSCO                             Cisco Systems, Inc.    Buy       0.011888
# ADBE                                      Adobe Inc.    Buy       0.011306
# IBM      International Business Machines Corporation   Hold       0.010534
# ...

# %%
msft = yf.Ticker('MSFT')
tech = yf.Sector(msft.info.get('sectorKey'))
software = yf.Industry(msft.info.get('industryKey'))
tech.top_companies
# Out:
#                                                 name rating  market weight
# symbol
# AAPL                                      Apple Inc.    Buy       0.187571
# NVDA                              NVIDIA Corporation    Buy       0.184803
# MSFT                           Microsoft Corporation    Buy       0.169441
# AVGO                                   Broadcom Inc.    Buy       0.042985
# ORCL                              Oracle Corporation    Buy       0.025601
# CRM                                 Salesforce, Inc.    Buy       0.014784
# AMD                     Advanced Micro Devices, Inc.    Buy       0.013463
# ACN                                    Accenture plc    Buy       0.012003
# CSCO                             Cisco Systems, Inc.    Buy       0.011897
# ADBE                                      Adobe Inc.    Buy       0.011337
# IBM      International Business Machines Corporation   Hold       0.010528
# ...

# %%
# Define a list of ticker symbols to download
tickerStrings = ['AAPL', 'MSFT']

# Download 2 days of data for each ticker, grouping by 'Ticker' to structure the DataFrame with multi-level columns
df = yf.download(tickerStrings, group_by='Ticker', period='5d')
df.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker                           MSFT                                      \
# Price                            Open        High         Low       Close
# Date
# 2024-10-21 00:00:00+00:00  416.119995  418.959991  413.750000  418.779999
# 2024-10-22 00:00:00+00:00  418.489990  430.579987  418.040009  427.510010
# 2024-10-23 00:00:00+00:00  430.859985  431.079987  422.529999  424.600006
# 2024-10-24 00:00:00+00:00  425.329987  425.980011  422.399994  424.730011
# 2024-10-25 00:00:00+00:00  426.899994  432.500000  426.600006  428.166992
#
# Ticker                                                 AAPL              \
# Price                       Adj Close    Volume        Open        High
# Date
# 2024-10-21 00:00:00+00:00  418.779999  14206100  234.449997  236.850006
# 2024-10-22 00:00:00+00:00  427.510010  25482200  233.889999  236.220001
# 2024-10-23 00:00:00+00:00  424.600006  19654400  234.080002  235.139999
# ...

# %%
df = df.stack(level=0)
df.head()
# Out:
# Price                              Adj Close       Close        High  \
# Date                      Ticker
# 2024-10-21 00:00:00+00:00 AAPL    236.479996  236.479996  236.850006
#                           MSFT    418.779999  418.779999  418.959991
# 2024-10-22 00:00:00+00:00 AAPL    235.860001  235.860001  236.220001
#                           MSFT    427.510010  427.510010  430.579987
# 2024-10-23 00:00:00+00:00 AAPL    230.759995  230.759995  235.139999
#
# Price                                    Low        Open    Volume
# Date                      Ticker
# 2024-10-21 00:00:00+00:00 AAPL    234.449997  234.449997  36254500
#                           MSFT    413.750000  416.119995  14206100
# 2024-10-22 00:00:00+00:00 AAPL    232.600006  233.889999  38846600
#                           MSFT    418.040009  418.489990  25482200
# 2024-10-23 00:00:00+00:00 AAPL    227.759995  234.080002  52287000

# %%
df = df.rename_axis(['Date', 'Ticker'])
df.head()
# Out:
# Price                              Adj Close       Close        High  \
# Date                      Ticker
# 2024-10-21 00:00:00+00:00 AAPL    236.479996  236.479996  236.850006
#                           MSFT    418.779999  418.779999  418.959991
# 2024-10-22 00:00:00+00:00 AAPL    235.860001  235.860001  236.220001
#                           MSFT    427.510010  427.510010  430.579987
# 2024-10-23 00:00:00+00:00 AAPL    230.759995  230.759995  235.139999
#
# Price                                    Low        Open    Volume
# Date                      Ticker
# 2024-10-21 00:00:00+00:00 AAPL    234.449997  234.449997  36254500
#                           MSFT    413.750000  416.119995  14206100
# 2024-10-22 00:00:00+00:00 AAPL    232.600006  233.889999  38846600
#                           MSFT    418.040009  418.489990  25482200
# 2024-10-23 00:00:00+00:00 AAPL    227.759995  234.080002  52287000

# %%
df = df.reset_index(level=1)
df.head()
# Out:
# Price                     Ticker   Adj Close       Close        High  \
# Date
# 2024-10-21 00:00:00+00:00   AAPL  236.479996  236.479996  236.850006
# 2024-10-21 00:00:00+00:00   MSFT  418.779999  418.779999  418.959991
# 2024-10-22 00:00:00+00:00   AAPL  235.860001  235.860001  236.220001
# 2024-10-22 00:00:00+00:00   MSFT  427.510010  427.510010  430.579987
# 2024-10-23 00:00:00+00:00   AAPL  230.759995  230.759995  235.139999
#
# Price                             Low        Open    Volume
# Date
# 2024-10-21 00:00:00+00:00  234.449997  234.449997  36254500
# 2024-10-21 00:00:00+00:00  413.750000  416.119995  14206100
# 2024-10-22 00:00:00+00:00  232.600006  233.889999  38846600
# 2024-10-22 00:00:00+00:00  418.040009  418.489990  25482200
# 2024-10-23 00:00:00+00:00  227.759995  234.080002  52287000

# %%
# Define a list of ticker symbols to download
tickerStrings = ['AAPL']

# Download 2 days of data for each ticker, grouping by 'Ticker' to structure the DataFrame with multi-level columns
df = yf.download(tickerStrings, group_by='Ticker', period='1y')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker                           AAPL                                      \
# Price                            Open        High         Low       Close
# Date
# 2023-10-26 00:00:00+00:00  170.369995  171.380005  165.669998  166.889999
# 2023-10-27 00:00:00+00:00  166.910004  168.960007  166.830002  168.220001
# 2023-10-30 00:00:00+00:00  169.020004  171.169998  168.869995  170.289993
# 2023-10-31 00:00:00+00:00  169.350006  170.899994  167.899994  170.770004
# 2023-11-01 00:00:00+00:00  171.000000  174.229996  170.119995  173.970001
# ...                               ...         ...         ...         ...
# 2024-10-21 00:00:00+00:00  234.449997  236.850006  234.449997  236.479996
# 2024-10-22 00:00:00+00:00  233.889999  236.220001  232.600006  235.860001
# 2024-10-23 00:00:00+00:00  234.080002  235.139999  227.759995  230.759995
# 2024-10-24 00:00:00+00:00  229.979996  230.820007  228.410004  230.570007
# ...
